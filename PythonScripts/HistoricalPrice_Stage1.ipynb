# %%
import MetaTrader5 as mt5
import pandas as pd
import os
from datetime import datetime, timedelta

# Define the currency pairs and timeframes
CURRENCY_PAIRS = [
    "EURUSD", "GBPUSD", "USDJPY", "USDCHF", "AUDUSD", "NZDUSD",
    "USDCAD", "EURGBP", "EURJPY", "EURCHF", "GBPJPY", "GBPCHF",
    "AUDJPY", "AUDNZD", "AUDCAD", "AUDCHF", "CADJPY", "CADCHF",
    "CHFJPY", "EURAUD", "EURNZD", "GBPAUD", "GBPNZD", "GBPCAD",
    "NZDJPY", "NZDCAD", "NZDCHF"
]

TIMEFRAMES = {
    "M1": mt5.TIMEFRAME_M1,
    "M5": mt5.TIMEFRAME_M5,
    "M15": mt5.TIMEFRAME_M15,
    "M30": mt5.TIMEFRAME_M30,
    "H1": mt5.TIMEFRAME_H1,
    "H4": mt5.TIMEFRAME_H4,
    "D1": mt5.TIMEFRAME_D1,
    "W1": mt5.TIMEFRAME_W1,
    "MN1": mt5.TIMEFRAME_MN1
}

OUTPUT_FOLDER = "Forex_Data"

def connect_mt5():
    """Connect to MT5."""
    if not mt5.initialize():
        print("Failed to initialize MT5:", mt5.last_error())
        return False
    print("Connected to MT5")
    return True

def fetch_data(symbol, timeframe, days=1):
    """
    Fetch historical OHLC data for a given symbol and timeframe.
    :param symbol: Symbol name (e.g., "EURUSD")
    :param timeframe: MT5 Timeframe constant
    :param days: Number of days of historical data to fetch
    :return: Pandas DataFrame with OHLC and tick volume
    """
    utc_from = datetime.now() - timedelta(days=days)
    utc_to = datetime.now()
    rates = mt5.copy_rates_range(symbol, timeframe, utc_from, utc_to)
    if rates is None:
        print(f"Failed to fetch data for {symbol} on {timeframe}: {mt5.last_error()}")
        return None
    df = pd.DataFrame(rates)
    return df

def save_csv(dataframe, filepath):
    """
    Save data to a CSV file.
    :param dataframe: DataFrame to save
    :param filepath: File path to save the data
    """
    dataframe["time"] = pd.to_datetime(dataframe["time"], unit="s")
    dataframe = dataframe[["time", "open", "high", "low", "close", "tick_volume"]]
    dataframe.to_csv(filepath, index=False)

def main():
    """Main function to fetch and save data."""
    if not connect_mt5():
        return

    # Create the main output folder if it doesn't exist
    if not os.path.exists(OUTPUT_FOLDER):
        os.mkdir(OUTPUT_FOLDER)

    for pair in CURRENCY_PAIRS:
        # Create a folder for each currency pair
        pair_folder = os.path.join(OUTPUT_FOLDER, pair)
        if not os.path.exists(pair_folder):
            os.mkdir(pair_folder)

        for tf_name, tf_value in TIMEFRAMES.items():
            # Define file name and path for each timeframe
            filename = f"{tf_name}.csv"
            filepath = os.path.join(pair_folder, filename)

            print(f"Fetching {pair} data for {tf_name}")
            df = fetch_data(pair, tf_value, days=1)  # Fetch last 1 day's data
            if df is not None:
                save_csv(df, filepath)
                print(f"Saved {tf_name} data for {pair} to {filepath}")

    mt5.shutdown()
    print("MT5 connection closed.")

if __name__ == "__main__":
    main()
# Out:
# Connected to MT5
# Fetching EURUSD data for M1
# Saved M1 data for EURUSD to Forex_Data\EURUSD\M1.csv
# Fetching EURUSD data for M5
# Saved M5 data for EURUSD to Forex_Data\EURUSD\M5.csv
# Fetching EURUSD data for M15
# Saved M15 data for EURUSD to Forex_Data\EURUSD\M15.csv
# Fetching EURUSD data for M30
# Saved M30 data for EURUSD to Forex_Data\EURUSD\M30.csv
# Fetching EURUSD data for H1
# Saved H1 data for EURUSD to Forex_Data\EURUSD\H1.csv
# Fetching EURUSD data for H4
# Saved H4 data for EURUSD to Forex_Data\EURUSD\H4.csv
# Fetching EURUSD data for D1
# Saved D1 data for EURUSD to Forex_Data\EURUSD\D1.csv
# Fetching EURUSD data for W1
# Saved W1 data for EURUSD to Forex_Data\EURUSD\W1.csv
# Fetching EURUSD data for MN1
# Saved MN1 data for EURUSD to Forex_Data\EURUSD\MN1.csv
# Fetching GBPUSD data for M1
# Saved M1 data for GBPUSD to Forex_Data\GBPUSD\M1.csv
# Fetching GBPUSD data for M5
# Saved M5 data for GBPUSD to Forex_Data\GBPUSD\M5.csv
# Fetching GBPUSD data for M15
# Saved M15 data for GBPUSD to Forex_Data\GBPUSD\M15.csv
# Fetching GBPUSD data for M30
# Saved M30 data for GBPUSD to Forex_Data\GBPUSD\M30.csv
# Fetching GBPUSD data for H1
# Saved H1 data for GBPUSD to Forex_Data\GBPUSD\H1.csv
# Fetching GBPUSD data for H4
# Saved H4 data for GBPUSD to Forex_Data\GBPUSD\H4.csv
# Fetching GBPUSD data for D1
# Saved D1 data for GBPUSD to Forex_Data\GBPUSD\D1.csv
# Fetching GBPUSD data for W1
# Saved W1 data for GBPUSD to Forex_Data\GBPUSD\W1.csv
# Fetching GBPUSD data for MN1
# Saved MN1 data for GBPUSD to Forex_Data\GBPUSD\MN1.csv
# Fetching USDJPY data for M1
# Saved M1 data for USDJPY to Forex_Data\USDJPY\M1.csv
# Fetching USDJPY data for M5
# Saved M5 data for USDJPY to Forex_Data\USDJPY\M5.csv
# Fetching USDJPY data for M15
# Saved M15 data for USDJPY to Forex_Data\USDJPY\M15.csv
# Fetching USDJPY data for M30
# Saved M30 data for USDJPY to Forex_Data\USDJPY\M30.csv
# Fetching USDJPY data for H1
# Saved H1 data for USDJPY to Forex_Data\USDJPY\H1.csv
# Fetching USDJPY data for H4
# Saved H4 data for USDJPY to Forex_Data\USDJPY\H4.csv
# Fetching USDJPY data for D1
# Saved D1 data for USDJPY to Forex_Data\USDJPY\D1.csv
# Fetching USDJPY data for W1
# Saved W1 data for USDJPY to Forex_Data\USDJPY\W1.csv
# Fetching USDJPY data for MN1
# Saved MN1 data for USDJPY to Forex_Data\USDJPY\MN1.csv
# Fetching USDCHF data for M1
# Saved M1 data for USDCHF to Forex_Data\USDCHF\M1.csv
# Fetching USDCHF data for M5
# Saved M5 data for USDCHF to Forex_Data\USDCHF\M5.csv
# Fetching USDCHF data for M15
# Saved M15 data for USDCHF to Forex_Data\USDCHF\M15.csv
# Fetching USDCHF data for M30
# Saved M30 data for USDCHF to Forex_Data\USDCHF\M30.csv
# Fetching USDCHF data for H1
# Saved H1 data for USDCHF to Forex_Data\USDCHF\H1.csv
# Fetching USDCHF data for H4
# Saved H4 data for USDCHF to Forex_Data\USDCHF\H4.csv
# Fetching USDCHF data for D1
# Saved D1 data for USDCHF to Forex_Data\USDCHF\D1.csv
# Fetching USDCHF data for W1
# Saved W1 data for USDCHF to Forex_Data\USDCHF\W1.csv
# Fetching USDCHF data for MN1
# Saved MN1 data for USDCHF to Forex_Data\USDCHF\MN1.csv
# Fetching AUDUSD data for M1
# Saved M1 data for AUDUSD to Forex_Data\AUDUSD\M1.csv
# Fetching AUDUSD data for M5
# Saved M5 data for AUDUSD to Forex_Data\AUDUSD\M5.csv
# Fetching AUDUSD data for M15
# Saved M15 data for AUDUSD to Forex_Data\AUDUSD\M15.csv
# Fetching AUDUSD data for M30
# Saved M30 data for AUDUSD to Forex_Data\AUDUSD\M30.csv
# Fetching AUDUSD data for H1
# Saved H1 data for AUDUSD to Forex_Data\AUDUSD\H1.csv
# Fetching AUDUSD data for H4
# Saved H4 data for AUDUSD to Forex_Data\AUDUSD\H4.csv
# Fetching AUDUSD data for D1
# Saved D1 data for AUDUSD to Forex_Data\AUDUSD\D1.csv
# Fetching AUDUSD data for W1
# Saved W1 data for AUDUSD to Forex_Data\AUDUSD\W1.csv
# Fetching AUDUSD data for MN1
# Saved MN1 data for AUDUSD to Forex_Data\AUDUSD\MN1.csv
# Fetching NZDUSD data for M1
# Saved M1 data for NZDUSD to Forex_Data\NZDUSD\M1.csv
# Fetching NZDUSD data for M5
# Saved M5 data for NZDUSD to Forex_Data\NZDUSD\M5.csv
# Fetching NZDUSD data for M15
# Saved M15 data for NZDUSD to Forex_Data\NZDUSD\M15.csv
# Fetching NZDUSD data for M30
# Saved M30 data for NZDUSD to Forex_Data\NZDUSD\M30.csv
# Fetching NZDUSD data for H1
# Saved H1 data for NZDUSD to Forex_Data\NZDUSD\H1.csv
# Fetching NZDUSD data for H4
# Saved H4 data for NZDUSD to Forex_Data\NZDUSD\H4.csv
# Fetching NZDUSD data for D1
# Saved D1 data for NZDUSD to Forex_Data\NZDUSD\D1.csv
# Fetching NZDUSD data for W1
# Saved W1 data for NZDUSD to Forex_Data\NZDUSD\W1.csv
# Fetching NZDUSD data for MN1
# Saved MN1 data for NZDUSD to Forex_Data\NZDUSD\MN1.csv
# Fetching USDCAD data for M1
# Saved M1 data for USDCAD to Forex_Data\USDCAD\M1.csv
# Fetching USDCAD data for M5
# Saved M5 data for USDCAD to Forex_Data\USDCAD\M5.csv
# Fetching USDCAD data for M15
# Saved M15 data for USDCAD to Forex_Data\USDCAD\M15.csv
# Fetching USDCAD data for M30
# Saved M30 data for USDCAD to Forex_Data\USDCAD\M30.csv
# Fetching USDCAD data for H1
# Saved H1 data for USDCAD to Forex_Data\USDCAD\H1.csv
# Fetching USDCAD data for H4
# Saved H4 data for USDCAD to Forex_Data\USDCAD\H4.csv
# Fetching USDCAD data for D1
# Saved D1 data for USDCAD to Forex_Data\USDCAD\D1.csv
# Fetching USDCAD data for W1
# Saved W1 data for USDCAD to Forex_Data\USDCAD\W1.csv
# Fetching USDCAD data for MN1
# Saved MN1 data for USDCAD to Forex_Data\USDCAD\MN1.csv
# Fetching EURGBP data for M1
# Saved M1 data for EURGBP to Forex_Data\EURGBP\M1.csv
# Fetching EURGBP data for M5
# Saved M5 data for EURGBP to Forex_Data\EURGBP\M5.csv
# Fetching EURGBP data for M15
# Saved M15 data for EURGBP to Forex_Data\EURGBP\M15.csv
# Fetching EURGBP data for M30
# Saved M30 data for EURGBP to Forex_Data\EURGBP\M30.csv
# Fetching EURGBP data for H1
# Saved H1 data for EURGBP to Forex_Data\EURGBP\H1.csv
# Fetching EURGBP data for H4
# Saved H4 data for EURGBP to Forex_Data\EURGBP\H4.csv
# Fetching EURGBP data for D1
# Saved D1 data for EURGBP to Forex_Data\EURGBP\D1.csv
# Fetching EURGBP data for W1
# Saved W1 data for EURGBP to Forex_Data\EURGBP\W1.csv
# Fetching EURGBP data for MN1
# Saved MN1 data for EURGBP to Forex_Data\EURGBP\MN1.csv
# Fetching EURJPY data for M1
# Saved M1 data for EURJPY to Forex_Data\EURJPY\M1.csv
# Fetching EURJPY data for M5
# Saved M5 data for EURJPY to Forex_Data\EURJPY\M5.csv
# Fetching EURJPY data for M15
# Saved M15 data for EURJPY to Forex_Data\EURJPY\M15.csv
# Fetching EURJPY data for M30
# Saved M30 data for EURJPY to Forex_Data\EURJPY\M30.csv
# Fetching EURJPY data for H1
# Saved H1 data for EURJPY to Forex_Data\EURJPY\H1.csv
# Fetching EURJPY data for H4
# Saved H4 data for EURJPY to Forex_Data\EURJPY\H4.csv
# Fetching EURJPY data for D1
# Saved D1 data for EURJPY to Forex_Data\EURJPY\D1.csv
# Fetching EURJPY data for W1
# Saved W1 data for EURJPY to Forex_Data\EURJPY\W1.csv
# Fetching EURJPY data for MN1
# Saved MN1 data for EURJPY to Forex_Data\EURJPY\MN1.csv
# Fetching EURCHF data for M1
# Saved M1 data for EURCHF to Forex_Data\EURCHF\M1.csv
# Fetching EURCHF data for M5
# Saved M5 data for EURCHF to Forex_Data\EURCHF\M5.csv
# Fetching EURCHF data for M15
# Saved M15 data for EURCHF to Forex_Data\EURCHF\M15.csv
# Fetching EURCHF data for M30
# Saved M30 data for EURCHF to Forex_Data\EURCHF\M30.csv
# Fetching EURCHF data for H1
# Saved H1 data for EURCHF to Forex_Data\EURCHF\H1.csv
# Fetching EURCHF data for H4
# Saved H4 data for EURCHF to Forex_Data\EURCHF\H4.csv
# Fetching EURCHF data for D1
# Saved D1 data for EURCHF to Forex_Data\EURCHF\D1.csv
# Fetching EURCHF data for W1
# Saved W1 data for EURCHF to Forex_Data\EURCHF\W1.csv
# Fetching EURCHF data for MN1
# Saved MN1 data for EURCHF to Forex_Data\EURCHF\MN1.csv
# Fetching GBPJPY data for M1
# Saved M1 data for GBPJPY to Forex_Data\GBPJPY\M1.csv
# Fetching GBPJPY data for M5
# Saved M5 data for GBPJPY to Forex_Data\GBPJPY\M5.csv
# Fetching GBPJPY data for M15
# Saved M15 data for GBPJPY to Forex_Data\GBPJPY\M15.csv
# Fetching GBPJPY data for M30
# Saved M30 data for GBPJPY to Forex_Data\GBPJPY\M30.csv
# Fetching GBPJPY data for H1
# Saved H1 data for GBPJPY to Forex_Data\GBPJPY\H1.csv
# Fetching GBPJPY data for H4
# Saved H4 data for GBPJPY to Forex_Data\GBPJPY\H4.csv
# Fetching GBPJPY data for D1
# Saved D1 data for GBPJPY to Forex_Data\GBPJPY\D1.csv
# Fetching GBPJPY data for W1
# Saved W1 data for GBPJPY to Forex_Data\GBPJPY\W1.csv
# Fetching GBPJPY data for MN1
# Saved MN1 data for GBPJPY to Forex_Data\GBPJPY\MN1.csv
# Fetching GBPCHF data for M1
# Saved M1 data for GBPCHF to Forex_Data\GBPCHF\M1.csv
# Fetching GBPCHF data for M5
# Saved M5 data for GBPCHF to Forex_Data\GBPCHF\M5.csv
# Fetching GBPCHF data for M15
# Saved M15 data for GBPCHF to Forex_Data\GBPCHF\M15.csv
# Fetching GBPCHF data for M30
# Saved M30 data for GBPCHF to Forex_Data\GBPCHF\M30.csv
# Fetching GBPCHF data for H1
# Saved H1 data for GBPCHF to Forex_Data\GBPCHF\H1.csv
# Fetching GBPCHF data for H4
# Saved H4 data for GBPCHF to Forex_Data\GBPCHF\H4.csv
# Fetching GBPCHF data for D1
# Saved D1 data for GBPCHF to Forex_Data\GBPCHF\D1.csv
# Fetching GBPCHF data for W1
# Saved W1 data for GBPCHF to Forex_Data\GBPCHF\W1.csv
# Fetching GBPCHF data for MN1
# Saved MN1 data for GBPCHF to Forex_Data\GBPCHF\MN1.csv
# Fetching AUDJPY data for M1
# Saved M1 data for AUDJPY to Forex_Data\AUDJPY\M1.csv
# Fetching AUDJPY data for M5
# Saved M5 data for AUDJPY to Forex_Data\AUDJPY\M5.csv
# Fetching AUDJPY data for M15
# Saved M15 data for AUDJPY to Forex_Data\AUDJPY\M15.csv
# Fetching AUDJPY data for M30
# Saved M30 data for AUDJPY to Forex_Data\AUDJPY\M30.csv
# Fetching AUDJPY data for H1
# Saved H1 data for AUDJPY to Forex_Data\AUDJPY\H1.csv
# Fetching AUDJPY data for H4
# Saved H4 data for AUDJPY to Forex_Data\AUDJPY\H4.csv
# Fetching AUDJPY data for D1
# Saved D1 data for AUDJPY to Forex_Data\AUDJPY\D1.csv
# Fetching AUDJPY data for W1
# Saved W1 data for AUDJPY to Forex_Data\AUDJPY\W1.csv
# Fetching AUDJPY data for MN1
# Saved MN1 data for AUDJPY to Forex_Data\AUDJPY\MN1.csv
# Fetching AUDNZD data for M1
# Saved M1 data for AUDNZD to Forex_Data\AUDNZD\M1.csv
# Fetching AUDNZD data for M5
# Saved M5 data for AUDNZD to Forex_Data\AUDNZD\M5.csv
# Fetching AUDNZD data for M15
# Saved M15 data for AUDNZD to Forex_Data\AUDNZD\M15.csv
# Fetching AUDNZD data for M30
# Saved M30 data for AUDNZD to Forex_Data\AUDNZD\M30.csv
# Fetching AUDNZD data for H1
# Saved H1 data for AUDNZD to Forex_Data\AUDNZD\H1.csv
# Fetching AUDNZD data for H4
# Saved H4 data for AUDNZD to Forex_Data\AUDNZD\H4.csv
# Fetching AUDNZD data for D1
# Saved D1 data for AUDNZD to Forex_Data\AUDNZD\D1.csv
# Fetching AUDNZD data for W1
# Saved W1 data for AUDNZD to Forex_Data\AUDNZD\W1.csv
# Fetching AUDNZD data for MN1
# Saved MN1 data for AUDNZD to Forex_Data\AUDNZD\MN1.csv
# Fetching AUDCAD data for M1
# Saved M1 data for AUDCAD to Forex_Data\AUDCAD\M1.csv
# Fetching AUDCAD data for M5
# Saved M5 data for AUDCAD to Forex_Data\AUDCAD\M5.csv
# Fetching AUDCAD data for M15
# Saved M15 data for AUDCAD to Forex_Data\AUDCAD\M15.csv
# Fetching AUDCAD data for M30
# Saved M30 data for AUDCAD to Forex_Data\AUDCAD\M30.csv
# Fetching AUDCAD data for H1
# Saved H1 data for AUDCAD to Forex_Data\AUDCAD\H1.csv
# Fetching AUDCAD data for H4
# Saved H4 data for AUDCAD to Forex_Data\AUDCAD\H4.csv
# Fetching AUDCAD data for D1
# Saved D1 data for AUDCAD to Forex_Data\AUDCAD\D1.csv
# Fetching AUDCAD data for W1
# Saved W1 data for AUDCAD to Forex_Data\AUDCAD\W1.csv
# Fetching AUDCAD data for MN1
# Saved MN1 data for AUDCAD to Forex_Data\AUDCAD\MN1.csv
# Fetching AUDCHF data for M1
# Saved M1 data for AUDCHF to Forex_Data\AUDCHF\M1.csv
# Fetching AUDCHF data for M5
# Saved M5 data for AUDCHF to Forex_Data\AUDCHF\M5.csv
# Fetching AUDCHF data for M15
# Saved M15 data for AUDCHF to Forex_Data\AUDCHF\M15.csv
# Fetching AUDCHF data for M30
# Saved M30 data for AUDCHF to Forex_Data\AUDCHF\M30.csv
# Fetching AUDCHF data for H1
# Saved H1 data for AUDCHF to Forex_Data\AUDCHF\H1.csv
# Fetching AUDCHF data for H4
# Saved H4 data for AUDCHF to Forex_Data\AUDCHF\H4.csv
# Fetching AUDCHF data for D1
# Saved D1 data for AUDCHF to Forex_Data\AUDCHF\D1.csv
# Fetching AUDCHF data for W1
# Saved W1 data for AUDCHF to Forex_Data\AUDCHF\W1.csv
# Fetching AUDCHF data for MN1
# Saved MN1 data for AUDCHF to Forex_Data\AUDCHF\MN1.csv
# Fetching CADJPY data for M1
# Saved M1 data for CADJPY to Forex_Data\CADJPY\M1.csv
# Fetching CADJPY data for M5
# Saved M5 data for CADJPY to Forex_Data\CADJPY\M5.csv
# Fetching CADJPY data for M15
# Saved M15 data for CADJPY to Forex_Data\CADJPY\M15.csv
# Fetching CADJPY data for M30
# Saved M30 data for CADJPY to Forex_Data\CADJPY\M30.csv
# Fetching CADJPY data for H1
# Saved H1 data for CADJPY to Forex_Data\CADJPY\H1.csv
# Fetching CADJPY data for H4
# Saved H4 data for CADJPY to Forex_Data\CADJPY\H4.csv
# Fetching CADJPY data for D1
# Saved D1 data for CADJPY to Forex_Data\CADJPY\D1.csv
# Fetching CADJPY data for W1
# Saved W1 data for CADJPY to Forex_Data\CADJPY\W1.csv
# Fetching CADJPY data for MN1
# Saved MN1 data for CADJPY to Forex_Data\CADJPY\MN1.csv
# Fetching CADCHF data for M1
# Saved M1 data for CADCHF to Forex_Data\CADCHF\M1.csv
# Fetching CADCHF data for M5
# Saved M5 data for CADCHF to Forex_Data\CADCHF\M5.csv
# Fetching CADCHF data for M15
# Saved M15 data for CADCHF to Forex_Data\CADCHF\M15.csv
# Fetching CADCHF data for M30
# Saved M30 data for CADCHF to Forex_Data\CADCHF\M30.csv
# Fetching CADCHF data for H1
# Saved H1 data for CADCHF to Forex_Data\CADCHF\H1.csv
# Fetching CADCHF data for H4
# Saved H4 data for CADCHF to Forex_Data\CADCHF\H4.csv
# Fetching CADCHF data for D1
# Saved D1 data for CADCHF to Forex_Data\CADCHF\D1.csv
# Fetching CADCHF data for W1
# Saved W1 data for CADCHF to Forex_Data\CADCHF\W1.csv
# Fetching CADCHF data for MN1
# Saved MN1 data for CADCHF to Forex_Data\CADCHF\MN1.csv
# Fetching CHFJPY data for M1
# Saved M1 data for CHFJPY to Forex_Data\CHFJPY\M1.csv
# Fetching CHFJPY data for M5
# Saved M5 data for CHFJPY to Forex_Data\CHFJPY\M5.csv
# Fetching CHFJPY data for M15
# Saved M15 data for CHFJPY to Forex_Data\CHFJPY\M15.csv
# Fetching CHFJPY data for M30
# Saved M30 data for CHFJPY to Forex_Data\CHFJPY\M30.csv
# Fetching CHFJPY data for H1
# Saved H1 data for CHFJPY to Forex_Data\CHFJPY\H1.csv
# Fetching CHFJPY data for H4
# Saved H4 data for CHFJPY to Forex_Data\CHFJPY\H4.csv
# Fetching CHFJPY data for D1
# Saved D1 data for CHFJPY to Forex_Data\CHFJPY\D1.csv
# Fetching CHFJPY data for W1
# Saved W1 data for CHFJPY to Forex_Data\CHFJPY\W1.csv
# Fetching CHFJPY data for MN1
# Saved MN1 data for CHFJPY to Forex_Data\CHFJPY\MN1.csv
# Fetching EURAUD data for M1
# Saved M1 data for EURAUD to Forex_Data\EURAUD\M1.csv
# Fetching EURAUD data for M5
# Saved M5 data for EURAUD to Forex_Data\EURAUD\M5.csv
# Fetching EURAUD data for M15
# Saved M15 data for EURAUD to Forex_Data\EURAUD\M15.csv
# Fetching EURAUD data for M30
# Saved M30 data for EURAUD to Forex_Data\EURAUD\M30.csv
# Fetching EURAUD data for H1
# Saved H1 data for EURAUD to Forex_Data\EURAUD\H1.csv
# Fetching EURAUD data for H4
# Saved H4 data for EURAUD to Forex_Data\EURAUD\H4.csv
# Fetching EURAUD data for D1
# Saved D1 data for EURAUD to Forex_Data\EURAUD\D1.csv
# Fetching EURAUD data for W1
# Saved W1 data for EURAUD to Forex_Data\EURAUD\W1.csv
# Fetching EURAUD data for MN1
# Saved MN1 data for EURAUD to Forex_Data\EURAUD\MN1.csv
# Fetching EURNZD data for M1
# Saved M1 data for EURNZD to Forex_Data\EURNZD\M1.csv
# Fetching EURNZD data for M5
# Saved M5 data for EURNZD to Forex_Data\EURNZD\M5.csv
# Fetching EURNZD data for M15
# Saved M15 data for EURNZD to Forex_Data\EURNZD\M15.csv
# Fetching EURNZD data for M30
# Saved M30 data for EURNZD to Forex_Data\EURNZD\M30.csv
# Fetching EURNZD data for H1
# Saved H1 data for EURNZD to Forex_Data\EURNZD\H1.csv
# Fetching EURNZD data for H4
# Saved H4 data for EURNZD to Forex_Data\EURNZD\H4.csv
# Fetching EURNZD data for D1
# Saved D1 data for EURNZD to Forex_Data\EURNZD\D1.csv
# Fetching EURNZD data for W1
# Saved W1 data for EURNZD to Forex_Data\EURNZD\W1.csv
# Fetching EURNZD data for MN1
# Saved MN1 data for EURNZD to Forex_Data\EURNZD\MN1.csv
# Fetching GBPAUD data for M1
# Saved M1 data for GBPAUD to Forex_Data\GBPAUD\M1.csv
# Fetching GBPAUD data for M5
# Saved M5 data for GBPAUD to Forex_Data\GBPAUD\M5.csv
# Fetching GBPAUD data for M15
# Saved M15 data for GBPAUD to Forex_Data\GBPAUD\M15.csv
# Fetching GBPAUD data for M30
# Saved M30 data for GBPAUD to Forex_Data\GBPAUD\M30.csv
# Fetching GBPAUD data for H1
# Saved H1 data for GBPAUD to Forex_Data\GBPAUD\H1.csv
# Fetching GBPAUD data for H4
# Saved H4 data for GBPAUD to Forex_Data\GBPAUD\H4.csv
# Fetching GBPAUD data for D1
# Saved D1 data for GBPAUD to Forex_Data\GBPAUD\D1.csv
# Fetching GBPAUD data for W1
# Saved W1 data for GBPAUD to Forex_Data\GBPAUD\W1.csv
# Fetching GBPAUD data for MN1
# Saved MN1 data for GBPAUD to Forex_Data\GBPAUD\MN1.csv
# Fetching GBPNZD data for M1
# Saved M1 data for GBPNZD to Forex_Data\GBPNZD\M1.csv
# Fetching GBPNZD data for M5
# Saved M5 data for GBPNZD to Forex_Data\GBPNZD\M5.csv
# Fetching GBPNZD data for M15
# Saved M15 data for GBPNZD to Forex_Data\GBPNZD\M15.csv
# Fetching GBPNZD data for M30
# Saved M30 data for GBPNZD to Forex_Data\GBPNZD\M30.csv
# Fetching GBPNZD data for H1
# Saved H1 data for GBPNZD to Forex_Data\GBPNZD\H1.csv
# Fetching GBPNZD data for H4
# Saved H4 data for GBPNZD to Forex_Data\GBPNZD\H4.csv
# Fetching GBPNZD data for D1
# Saved D1 data for GBPNZD to Forex_Data\GBPNZD\D1.csv
# Fetching GBPNZD data for W1
# Saved W1 data for GBPNZD to Forex_Data\GBPNZD\W1.csv
# Fetching GBPNZD data for MN1
# Saved MN1 data for GBPNZD to Forex_Data\GBPNZD\MN1.csv
# Fetching GBPCAD data for M1
# Saved M1 data for GBPCAD to Forex_Data\GBPCAD\M1.csv
# Fetching GBPCAD data for M5
# Saved M5 data for GBPCAD to Forex_Data\GBPCAD\M5.csv
# Fetching GBPCAD data for M15
# Saved M15 data for GBPCAD to Forex_Data\GBPCAD\M15.csv
# Fetching GBPCAD data for M30
# Saved M30 data for GBPCAD to Forex_Data\GBPCAD\M30.csv
# Fetching GBPCAD data for H1
# Saved H1 data for GBPCAD to Forex_Data\GBPCAD\H1.csv
# Fetching GBPCAD data for H4
# Saved H4 data for GBPCAD to Forex_Data\GBPCAD\H4.csv
# Fetching GBPCAD data for D1
# Saved D1 data for GBPCAD to Forex_Data\GBPCAD\D1.csv
# Fetching GBPCAD data for W1
# Saved W1 data for GBPCAD to Forex_Data\GBPCAD\W1.csv
# Fetching GBPCAD data for MN1
# Saved MN1 data for GBPCAD to Forex_Data\GBPCAD\MN1.csv
# Fetching NZDJPY data for M1
# Saved M1 data for NZDJPY to Forex_Data\NZDJPY\M1.csv
# Fetching NZDJPY data for M5
# Saved M5 data for NZDJPY to Forex_Data\NZDJPY\M5.csv
# Fetching NZDJPY data for M15
# Saved M15 data for NZDJPY to Forex_Data\NZDJPY\M15.csv
# Fetching NZDJPY data for M30
# Saved M30 data for NZDJPY to Forex_Data\NZDJPY\M30.csv
# Fetching NZDJPY data for H1
# Saved H1 data for NZDJPY to Forex_Data\NZDJPY\H1.csv
# Fetching NZDJPY data for H4
# Saved H4 data for NZDJPY to Forex_Data\NZDJPY\H4.csv
# Fetching NZDJPY data for D1
# Saved D1 data for NZDJPY to Forex_Data\NZDJPY\D1.csv
# Fetching NZDJPY data for W1
# Saved W1 data for NZDJPY to Forex_Data\NZDJPY\W1.csv
# Fetching NZDJPY data for MN1
# Saved MN1 data for NZDJPY to Forex_Data\NZDJPY\MN1.csv
# Fetching NZDCAD data for M1
# Saved M1 data for NZDCAD to Forex_Data\NZDCAD\M1.csv
# Fetching NZDCAD data for M5
# Saved M5 data for NZDCAD to Forex_Data\NZDCAD\M5.csv
# Fetching NZDCAD data for M15
# Saved M15 data for NZDCAD to Forex_Data\NZDCAD\M15.csv
# Fetching NZDCAD data for M30
# Saved M30 data for NZDCAD to Forex_Data\NZDCAD\M30.csv
# Fetching NZDCAD data for H1
# Saved H1 data for NZDCAD to Forex_Data\NZDCAD\H1.csv
# Fetching NZDCAD data for H4
# Saved H4 data for NZDCAD to Forex_Data\NZDCAD\H4.csv
# Fetching NZDCAD data for D1
# Saved D1 data for NZDCAD to Forex_Data\NZDCAD\D1.csv
# Fetching NZDCAD data for W1
# Saved W1 data for NZDCAD to Forex_Data\NZDCAD\W1.csv
# Fetching NZDCAD data for MN1
# Saved MN1 data for NZDCAD to Forex_Data\NZDCAD\MN1.csv
# Fetching NZDCHF data for M1
# Saved M1 data for NZDCHF to Forex_Data\NZDCHF\M1.csv
# Fetching NZDCHF data for M5
# Saved M5 data for NZDCHF to Forex_Data\NZDCHF\M5.csv
# Fetching NZDCHF data for M15
# Saved M15 data for NZDCHF to Forex_Data\NZDCHF\M15.csv
# Fetching NZDCHF data for M30
# Saved M30 data for NZDCHF to Forex_Data\NZDCHF\M30.csv
# Fetching NZDCHF data for H1
# Saved H1 data for NZDCHF to Forex_Data\NZDCHF\H1.csv
# Fetching NZDCHF data for H4
# Saved H4 data for NZDCHF to Forex_Data\NZDCHF\H4.csv
# Fetching NZDCHF data for D1
# Saved D1 data for NZDCHF to Forex_Data\NZDCHF\D1.csv
# Fetching NZDCHF data for W1
# Saved W1 data for NZDCHF to Forex_Data\NZDCHF\W1.csv
# Fetching NZDCHF data for MN1
# Saved MN1 data for NZDCHF to Forex_Data\NZDCHF\MN1.csv
# MT5 connection closed.

# %%
import MetaTrader5 as mt5
print("MetaTrader5 version:", mt5.__version__)
# Out:
# MetaTrader5 version: 5.0.4424
